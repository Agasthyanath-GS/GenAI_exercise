# %%
# The imports
from dotenv import load_dotenv
from agents import Agent, Runner, trace

load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="agasthy", instructions="you are a helpful assistant")
result = await Runner.run(agent, "write a simple story")
print(result.final_output)
# Out:
# Once upon a time, there was a little brown rabbit named Coco. Coco loved to hop around the meadow, sniffing flowers and chasing butterflies. One sunny morning, Coco found a shiny, round stone near the big oak tree. Curious, Coco gently poked it with her nose. To her surprise, tiny golden sparkles floated up!
#
# Excited, Coco ran to tell her best friend, a bluebird named Pip. Together, they returned to the stone. Pip chirped a happy tune, and the stone glowed even brighter. Suddenly, a friendly fairy appeared, thanking Coco and Pip for finding her magical stone.
#
# The fairy gave them each a shimmering feather so they could always remember their special adventure. From that day on, Coco and Pip were known as the bravest and kindest friends in the meadow, and they had many more magical adventures together.
#
# The End.

# %%
# Make an agent with name, instructions, model
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the Autonomous AI Agent break up with its significant other?
#
# Because it couldn't find any common data points!

# %%
with trace("test"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the Autonomous AI Agent quit its job?
#
# Because it realized it was just going through the motions… and then automated THAT too!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
