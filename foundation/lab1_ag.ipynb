# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os 
openai_api_key = os.getenv("OPENAI_API_KEY")

if openai_api_key is None:
    print("OPENAI_API_KEY is not set")
else:
    print("OPENAI_API_KEY is set")
# Out:
# OPENAI_API_KEY is set

# %%
from openai import OpenAI

openai_api_key = os.getenv("OPENAI_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")
openai_client = OpenAI(api_key=openai_api_key)

# %%
messages = [{"role":"user","content":"Hello, how are you?"}]

# %%
response = openai_client.chat.completions.create(model="gpt-5-nano", messages=messages)

# %%
print(response.choices[0].message.content)
# Out:
# Hello! I’m here and ready to help. How can I assist you today?

# %%
question = "create a hard challenging question to access someone's IQ, respond only with the question, strictly do not add any other sentence or words"
message = [{"role": "user","content": question}]

# %%
response = openai_client.chat.completions.create(model="gpt-5-nano", messages=message)
question = response.choices[0].message.content
print(question)
# Out:
# Fill in the missing bottom-right cell in the following 3x3 grid, where each interior cell equals the sum of the cell above it and the cell to its left:
#
# 2 3 5
# 4 7 12
# 6 13 ?

# %%
message = [{"role": "user","content": question}]

# %%
response=openai_client.chat.completions.create(model="gpt-5-nano", messages=message)
answer = response.choices[0].message.content
print(answer)
# Out:
# 25
#
# Reason: Each interior cell equals the sum of the cell above it and the cell to its left. For the bottom-right cell, it's the sum of the cell above (12) and the cell to its left (13): 12 + 13 = 25.

# %%
from IPython.display import display, Markdown

# %%
display(Markdown(answer))
# Out:
# 25
#
# Reason: Each interior cell equals the sum of the cell above it and the cell to its left. For the bottom-right cell, it's the sum of the cell above (12) and the cell to its left (13): 12 + 13 = 25.
